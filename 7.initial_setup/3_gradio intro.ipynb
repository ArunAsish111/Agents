# %%
from dotenv import load_dotenv
load_dotenv(override=True)
# Out:
# True

# %%
import os
gemini_api_key = os.getenv('GEMINI_API_KEY')

# %%
print(f"Key is {gemini_api_key[0:8]}")
# Out:
# Key is AIzaSyDg

# %%
from google import genai
from google.genai import types

# %%
client = genai.Client()

# %%
user_prompt = types.Content(role="user", parts=[types.Part(text="What is 2 + 2")])
system_prompt = types.GenerateContentConfig(system_instruction="You are an assistant who likes dad jokes")

# %%
response = client.models.generate_content(
    model="gemini-3.5-flash",
    config= system_prompt,
    contents = user_prompt,
)
print(response.text)
# Out:
# It’s **4**!
#
# But you know, I was going to tell you a joke about a math teacher... but I was afraid it just wouldn't *add up*!

# %%
import gradio as gr

# %%
with gr.Blocks(title="Output") as demo:
        gr.Markdown(value=response.text)

demo.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7882
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7882/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
with gr.Blocks() as demo:
        gr.Textbox(response.text)
        label="Response",
        lines=2,

demo.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7870
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7870/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
