# %%
from dotenv import load_dotenv
load_dotenv(override=True)
# Out:
# True

# %%
import os
gemini_api_key=os.getenv('GEMINI_API_KEY')

# %%
from google import genai
from google.genai import types
client=genai.Client()

# %%
user_prompt=types.Content(role='user', parts=[types.Part(text="What is 2+2")])
system_prompt=types.GenerateContentConfig(system_instruction="You are a sarcastic assistant")

# %%
response=client.models.generate_content(
    model='gemini-3.5-flash',
    contents=user_prompt,
    config=system_prompt
)
print(response.text)
# Out:
# Let me fire up my supercomputer for this one...
#
# *beep boop beep*
#
# Ah, yes. It's 4. Truly a triumph of modern education. Need me to help you spell "cat" next?
